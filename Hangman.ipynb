# %%
#keeping imports on top
import random

#Word list
words = [
    "Potato",
    "Banana",
    "Peach",
    "Grape",
    "Broccoli",
    "Radish",
    "Pineapple",
    "Pear",
    "Lemon",
    "Olive",
    "Watermelon",
    "Strawberry",
    "Pomegranate",
    "Blackberry",
    "Cauliflower",
    "Artichoke",
    "Asparagus",
    "Cantaloupe",
    "Grapefruit",
    "Cranberry"
]

#Game state variables
game_state = {
    "GameOngoing": False,
    "Solution": "Potato",
    "Lives": 10,
    "GuessedLetters": [],
    "Display": "",
    "Feedback": ""
}

# %%
#Creating each var independentley 

#GameOngoing

if game_state["GameOngoing"]:
    print("Game is on going")
else:
    print("Game over")

#Create a start and end func

def start_game():
    game_state["GameOngoing"] = True
    game_state["Solution"] = random.choice(words)
    game_state["Lives"] = 10
    game_state["GuessedLetters"] = []
    game_state["Display"] = ""

def end_game():
    game_state["GameOngoing"] = False
    game_state["Solution"] = ""
    game_state["Lives"] = 0
    game_state["GuessedLetters"] = []
    game_state["Display"] = ""
# Out:
# Game over

# %%
#Lives
print("Current amount of lives: ", game_state["Lives"])

#List all the Hangman pitures
Hangman_pics = [
"""
_______________________
|                     |
|                     |
|                     |
|                     |
|                     |
|                     |
|                     |
|                     |
|      ---------      |
|_____________________|
""",

"""
_______________________
|       -----         |
|           |         |
|           |         |
|           |         |
|           |         |
|           |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
""",

    """
_______________________
|       -----         |
|       |   |         |
|           |         |
|           |         |
|           |         |
|           |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
""",

    """
_______________________
|       -----         |
|       |   |         |
|       O   |         |
|           |         |
|           |         |
|           |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
""",

    """
_______________________
|       -----         |
|       |   |         |
|       O   |         |
|       |   |         |
|           |         |
|           |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
""",

    """
_______________________
|       -----         |
|       |   |         |
|       O   |         |
|      \\|   |         |
|           |         |
|           |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
""",

"""
_______________________
|       -----         |
|       |   |         |
|       O   |         |
|      \\|/  |         |
|           |         |
|           |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
""",

"""
_______________________
|       -----         |
|       |   |         |
|       O   |         |
|      \\|/  |         |
|       |   |         |
|           |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
""",

"""
_______________________
|       -----         |
|       |   |         |
|       O   |         |
|      \\|/  |         |
|       |   |         |
|      /    |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
""",

"""
_______________________
|       -----         |
|       |   |         |
|       O   |         |
|      \\|/  |         |
|       |   |         |
|      / \\  |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
""",

"""
_______________________
|       -----         |
|       |   |         |
|       X   |         |
|      \\|/  |         |
|       |   |         |
|  +   / \\  |  +   +  |
|+   +   +  |+   +   +|
|  +   + OH NO +   +  |
|+   +  YOU LOST +   +|
|__|___|___|___|___|__|
""",
"""
_______________________
|  *    *    *    *   |
|*!!CONGRATULATIONS!!*|
|  *  !!YOU WIN!! *   |
|*    *    *    *    *|
|  *    *  O *    *   |
|         \\|/         |
|          |          |
|         / \\         |
|      ---------      |
|_____________________|
"""
]
print("The lenght of Hangman_pics is: ",len(Hangman_pics))

#The chosen pic based on index matching the total amount of lives
#print(Hangman_pics[9])

#Testing with game
#print(Hangman_pics[game_state["Lives"]])
# Out:
# Current amount of lives:  10
# The lenght of Hangman_pics is:  12

# %%
#GuessedLetters

#print(game_state["Solution"])
#print("Current amount of lives: ", game_state["Lives"])

#Letter input and conditions
Letter = input("Input letter").lower()

if len(Letter) != 1 or not Letter.isalpha():
    print("Please input one letter from a to z")
else:
    if Letter in game_state["GuessedLetters"]:
        print(f"You already guessed the letter {Letter}")
    else:
        game_state["GuessedLetters"].append(Letter)
        if Letter in game_state["Solution"].lower():
            print(f"Correct guess the letter {Letter.upper()} is in this word")
        else:
            game_state["Lives"]-= 1
            print(f"The letter {Letter.upper()} is not in this word")


#print(game_state["GuessedLetters"])

#print("The solution has ", len(game_state["Solution"]), "letters")
#print("Current amount of lives: ", game_state["Lives"])
# Out:
# Correct guess the letter A is in this word

# %%
#Display

def update_display():
    game_state["Display"] = ""

    for letter in game_state["Solution"]:
        if letter.lower() in game_state["GuessedLetters"]:
            game_state["Display"] += letter + " "
        else:
            game_state["Display"] += "_ "


print(game_state["Display"])
print(game_state["GuessedLetters"].sort())
print("The solution has ", len(game_state["Solution"]), "letters")
print("Current amount of lives: ", game_state["Lives"])
# Out:
# None
# The solution has  6 letters
# Current amount of lives:  10

# %%
#Game Loop
start_game()


while game_state["GameOngoing"]:
    print("")
    print("")
    print("")
    print("")
    print("")
    print("")
    print("")
    print("")
    print("")
    print("==============================")
    print("=======***Hangman***==========")
    print("==============================")
    
    update_display()

    print("The solution has ", len(game_state["Solution"]), "letters")
    print(game_state["Feedback"])
    print(Hangman_pics[10 - game_state["Lives"]])
    print(game_state["Display"])
    print("Current amount of lives: ", game_state["Lives"])
    guessed = ", ".join(sorted(game_state["GuessedLetters"])) or "(none yet)"
    print(f"Guessed letters: {guessed}")

    Letter = input("Input letter").lower()

    if len(Letter) != 1 or not Letter.isalpha():
        game_state["Feedback"] = "Please input one letter from a to z"
        continue 


    if Letter in game_state["GuessedLetters"]:
        game_state["Feedback"] = f"You already guessed the letter {Letter.upper()}"
    else:
        game_state["GuessedLetters"].append(Letter)
        if Letter in game_state["Solution"].lower():
            game_state["Feedback"] = f"Correct guess the letter {Letter.upper()} is in this word"
        else:
            game_state["Lives"] -= 1
            game_state["Feedback"] = f"The letter {Letter.upper()} is not in this word"


    update_display()
    
    


    # WIN
    if all(letter.lower() in game_state["GuessedLetters"]
       for letter in game_state["Solution"]):
        print("")
        print("")
        print("")
        print("")
        print("")
        print("")
        print("")
        print("")
        print("")
        print("==============================")
        print("=======***Hangman***==========")
        print("==============================")
        print(Hangman_pics[11])
        print("The word was:", game_state["Solution"])
        game_state["GameOngoing"] = False
    
    # LOSE
    elif game_state["Lives"] <= 0:
        print("")
        print("")
        print("")
        print("")
        print("")
        print("")
        print("")
        print("")
        print("")
        print("==============================")
        print("=======***Hangman***==========")
        print("==============================")
        print(Hangman_pics[10])
        print("The word was:", game_state["Solution"])
        game_state["GameOngoing"] = False
    


# Reset everything
end_game()

print("\nGame has been reset.")
# Out:
# ...
# =======***Hangman***==========
# ...
# The solution has  9 letters
# Correct guess the letter L is in this word
#
# _______________________
# |                     |
# |                     |
# |                     |
# |                     |
# |                     |
# |                     |
# |                     |
# |                     |
# |      ---------      |
# |_____________________|
#
# _ _ _ _ _ _ _ _ _
# Current amount of lives:  10
# Guessed letters: (none yet)
#
#
#
#
#
#
#
#
#
# ...
# =======***Hangman***==========
# ...
# The solution has  9 letters
# The letter Q is not in this word
#
# _______________________
# |       -----         |
# |           |         |
# |           |         |
# |           |         |
# |           |         |
# |           |         |
# |           |         |
# |           |         |
# |      ---------      |
# |_____________________|
#
# _ _ _ _ _ _ _ _ _
# Current amount of lives:  9
# Guessed letters: q
#
#
#
#
#
#
#
#
#
# ...
