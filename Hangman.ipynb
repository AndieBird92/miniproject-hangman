# %%
#keeping imports on top
import random

#10 word list
words = [
    "Potato",
    "Banana",
    "Peach",
    "Grape",
    "Broccoli",
    "Radish",
    "Pineapple",
    "Pear",
    "Lemon",
    "Olive",
    "Watermelon",
    "Strawberry",
    "Pomegranate",
    "Blackberry",
    "Cauliflower",
    "Artichoke",
    "Asparagus",
    "Cantaloupe",
    "Grapefruit",
    "Cranberry"
]

#Game state variables
game_state = {
    "GameOngoing": False,
    "Solution": "Potato",
    "Lives": 10,
    "GuessedLetters": [],
    "Display": ""
}

# %%
#Creating each var independentley 

#GameOngoing

if game_state["GameOngoing"]:
    print("Game is on going")
else:
    print("Game over")

#Create a start and end func

def start_game():
    game_state["GameOngoing"] = True
    game_state["Solution"] = random.choice(words)
    game_state["Lives"] = 10
    game_state["GuessedLetters"] = []
    game_state["Display"] = ""

def end_game():
    game_state["GameOngoing"] = False
    game_state["Solution"] = ""
    game_state["Lives"] = 0
    game_state["GuessedLetters"] = []
    game_state["Display"] = ""
# Out:
# Game over

# %%
#Sloution

game_state["Solution"] = random.choice(words)

print(game_state["Solution"])
print("The solution has ", len(game_state["Solution"]), "letters")
# Out:
# Pineapple
# The solution has  9 letters

# %%
#Lives
print("Current amount of lives: ", game_state["Lives"])

#List all the Hangman pitures
Hangman_pics = [
    """
_______________________
|                     |
|                     |
|                     |
|                     |
|                     |
|                     |
|                     |
|                     |
|      ---------      |
|_____________________|
""",

    """
_______________________
|       -----         |
|           |         |
|           |         |
|           |         |
|           |         |
|           |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
""",

    """
_______________________
|       -----         |
|       |   |         |
|           |         |
|           |         |
|           |         |
|           |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
""",

    """
_______________________
|       -----         |
|       |   |         |
|       O   |         |
|           |         |
|           |         |
|           |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
""",

    """
_______________________
|       -----         |
|       |   |         |
|       O   |         |
|       |   |         |
|           |         |
|           |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
""",

    """
_______________________
|       -----         |
|       |   |         |
|       O   |         |
|      \\|/  |         |
|           |         |
|           |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
""",

    """
_______________________
|       -----         |
|       |   |         |
|       O   |         |
|      \\|/  |         |
|           |         |
|           |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
""",

    """
_______________________
|       -----         |
|       |   |         |
|       O   |         |
|      \\|/  |         |
|       |   |         |
|           |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
""",

    """
_______________________
|       -----         |
|       |   |         |
|       O   |         |
|      \\|/  |         |
|       |   |         |
|      /    |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
""",

    """
_______________________
|       -----         |
|       |   |         |
|       O   |         |
|      \\|/  |         |
|       |   |         |
|      / \\  |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
""",

    """
_______________________
|       -----         |
|       |   |         |
|       X   |         |
|      \\|/  |         |
|       |   |         |
|      / \\  |         |
|           |         |
|           |         |
|      ---------      |
|_____________________|
"""
]
print("The lenght of Hangman_pics is: ",len(Hangman_pics))

#The chosen pic based on index matching the total amount of lives
#print(Hangman_pics[1])

#Testing with game
#print(Hangman_pics[game_state["Lives"]])
# Out:
# Current amount of lives:  10
# The lenght of Hangman_pics is:  11

# %%
#GuessedLetters

print(game_state["Solution"])
print("Current amount of lives: ", game_state["Lives"])

#Letter input and conditions
Letter = input("Input letter").lower()

if Letter in game_state["GuessedLetters"]:
    print(f"You already guessed the letter {Letter}")
else:
    game_state["GuessedLetters"].append(Letter)
    if Letter in game_state["Solution"].lower():
           print(f"Correct guess the letter {Letter.upper()} is in this word")
    else:
           game_state["Lives"]-= 1
           print(f"The letter {Letter.upper()} is not in this word")


print(game_state["GuessedLetters"])

print("The solution has ", len(game_state["Solution"]), "letters")
print("Current amount of lives: ", game_state["Lives"])
# Out:
# Pineapple
# Current amount of lives:  10
# Correct guess the letter E is in this word
# ['e']
# The solution has  9 letters
# Current amount of lives:  10

# %%
#Display

def update_display():
    game_state["Display"] = ""

    for letter in game_state["Solution"]:
        if letter.lower() in game_state["GuessedLetters"]:
            game_state["Display"] += letter
        else:
            game_state["Display"] += "_ "


print(game_state["Display"])
print(game_state["GuessedLetters"])
print("The solution has ", len(game_state["Solution"]), "letters")
print("Current amount of lives: ", game_state["Lives"])
# Out:
# ['e']
# The solution has  9 letters
# Current amount of lives:  10

# %%
#Game Loop
start_game()

while game_state["GameOngoing"]:
    
    update_display()

    print("The solution has ", len(game_state["Solution"]), "letters")
    print("Current amount of lives: ", game_state["Lives"])
    print(Hangman_pics[10 - game_state["Lives"]])
    print(game_state["Display"])
    print(f"Guessed letters: {game_state["GuessedLetters"]}")

    Letter = input("Input letter").lower()
    

    if Letter in game_state["GuessedLetters"]:
        print(f"You already guessed the letter {Letter}")
    else:
        game_state["GuessedLetters"].append(Letter)
        if Letter in game_state["Solution"].lower():
            print(f"Correct guess the letter {Letter.upper()} is in this word")
        else:
            game_state["Lives"]-= 1
            print(f"The letter {Letter.upper()} is not in this word")

    update_display()
     

    # WIN
    if  game_state["Display"].lower() == game_state["Solution"].lower():
        print("\nYou win!")
        print("The word was:", game_state["Solution"])
        game_state["GameOngoing"] = False

    # LOSE
    elif game_state["Lives"] <= 0:
        print("\nGame over!")
        print(Hangman_pics[10])
        print("The word was:", game_state["Solution"])
        game_state["GameOngoing"] = False

# Reset everything
end_game()

print("\nGame has been reset.")
# Out:
# The solution has  9 letters
# Current amount of lives:  10
#
# _______________________
# |                     |
# |                     |
# |                     |
# |                     |
# |                     |
# |                     |
# |                     |
# |                     |
# |      ---------      |
# |_____________________|
#
# _ _ _ _ _ _ _ _ _
# Guessed letters: []
# Correct guess the letter E is in this word
# The solution has  9 letters
# Current amount of lives:  10
#
# _______________________
# |                     |
# |                     |
# |                     |
# |                     |
# |                     |
# |                     |
# |                     |
# |                     |
# |      ---------      |
# |_____________________|
#
# _ _ _ _ _ e_ _ _
# Guessed letters: ['e']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 14
#      10     print(Hangman_pics[10 - game_state["Lives"]])
#      11     print(game_state["Display"])
#      12     print(f"Guessed letters: {game_state["GuessedLetters"]}")
#      13
# ---> 14     Letter = input("Input letter").lower()
#      15
#      16
#      17     if Letter in game_state["GuessedLetters"]:
#
# File c:\Users\asus\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# File c:\Users\asus\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1320, in Kernel._input_request(self, prompt, ident, parent, password)
#    1317 except KeyboardInterrupt:
#    1318     # re-raise KeyboardInterrupt, to truncate traceback
#    1319     msg = "Interrupted by user"
# -> 1320     raise KeyboardInterrupt(msg) from None
#    1321 except Exception:
#    1322     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
