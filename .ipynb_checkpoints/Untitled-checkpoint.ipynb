# %%
A list containing at least 10 words:

words = [ "Potato", "Banana", "Peach", "Grape", "Broccoli", "Radish", "Pineapple", "Pear", "Lemon", "Olive" ]


A game state dictionary:
how many lives i have currently 
letters guessed
word that im guessing
what letter i want to input next
if the game is ongoing

game_state = {
    "GameOngoing": True/False ,
    "Solution": word ,
    "Lives": TotalLives- wrong guesses,
    "GuessedLetters": list
     "letter input": ""
}

# %%
words = [
    "Potato",
    "Banana",
    "Peach",
    "Grape",
    "Broccoli",
    "Radish",
    "Pineapple",
    "Pear",
    "Lemon",
    "Olive"
]

game_state = {
    "GameOngoing": True,
    "Solution": "Potato",
    "Lives": 5,
    "GuessedLetters": [],
    "letter input": ""
}

# %%
game_state = {
    "GameOngoing": True,
    "Solution": "Potato",
    "Lives": 5,
    "GuessedLetters": ["a"],
    "letter input": ""
}
